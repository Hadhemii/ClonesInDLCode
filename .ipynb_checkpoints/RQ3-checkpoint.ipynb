# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
from pydriller import RepositoryMining, git_repository
#from pydriller.domain.commit import ModificationType
from pprint import pprint
import csv, os, re
import datetime

# %%
bugs_keywords = ["fixed ", " bug", "fixes ","fix ",
        " fix", " fixed", " fixes", "crash","solves", " resolves",
"resolves ", " issue", "issue ", "regression", "fall back", "assertion", "coverity", "reproducible",
"stack-wanted", "steps-wanted", "testcase", "failur", "fail", "npe ",
" npe", "except", "broken", "differential testing", "error", "addresssanitizer",
"hang ", " hang", "permaorange", "random orange", "intermittent", "test fix",
"steps to reproduce", "crash", "assertion", "failure", "leak", "stack trace", "heap overflow",
        "freez", "str:", "problem ", " problem", " overflow", "overflow ", "avoid ",
        " avoid",  "workaround ", " workaround", "break ", " break", " stop", "stop "]

# %%
def get_modified_lines(repository, commits, filename):
    for commit in RepositoryMining(repository, only_commits=commits, only_modifications_with_file_types=['.py']).traverse_commits():
        for modified_file in commit.modifications:
            if modified_file.filename == filename:
                parsed_diff =modified_file.diff_parsed
                lines=set()
                for values in parsed_diff['added']:
                    lines.add(values[0])
                return lines

# %%
with open('output_data/bug_fix_commits_lines.csv', 'w', newline='') as output_file:
    output_writer = csv.writer(output_file)
    output_writer.writerow(['repoName','bug_fix_commit','bug_fix_file','bug_fix_lines'])
    repositories=["systems/dl/adanet/","systems/dl/BerryNet/","systems/dl/DeepCTR/","systems/dl/keras-applications/","systems/dl/nn-wtf/","systems/dl/ranking/"]
    for repository in repositories:
        gr = git_repository.GitRepository(repository)
        repoName=repository.replace('systems/dl/','').replace('/','')
        print(repoName)
        for commit in RepositoryMining(repository).traverse_commits():
            if any(bug_word in commit.msg for bug_word in bugs_keywords):
                for modified_file in commit.modifications:
                    if modified_file.filename.endswith('.py'):
                        parsed_diff =modified_file.diff_parsed
                        lines=set()
                        if modified_file.new_path:
                            file_url = modified_file.new_path.replace('\\','/')
                        else:
                            file_url = modified_file.old_path.replace('\\','/')
                        for values in parsed_diff['added']:
                            lines.add(values[0])
                        if (commit.hash == '48599be4e389124fa736272ca91ca77fefcba624') and (file_url == 'adanet/core/iteration_test.py'):
                            print(repoName,commit.hash, file_url,sorted(lines))
                        #print(repoName, commit.msg,commit.hash, modified_file.filename,sorted(lines))
                        output_writer.writerow([repoName,commit.hash,file_url,sorted(lines)])
# Out:
# adanet
# adanet 48599be4e389124fa736272ca91ca77fefcba624 adanet/core/iteration_test.py [34, 35, 36, 37, 38, 39, 40, 47, 54, 55, 62, 69, 76, 83, 92, 153, 169, 328, 333, 340]
# BerryNet
# DeepCTR
# keras-applications
# nn-wtf
# ranking

# %%
repositories=["systems/dl/adanet/"]
for repository in repositories:
    gr = git_repository.GitRepository(repository)
    repoName=repository.replace('systems/dl/','').replace('/','')
    print(repoName)
    for commit in RepositoryMining(repository).traverse_commits():
        if any(bug_word in commit.msg for bug_word in bugs_keywords):
            for modified_file in commit.modifications:
                if modified_file.filename.endswith('.py'):
                    parsed_diff =modified_file.diff_parsed
                    #print(parsed_diff)
                    lines=set()
                    if modified_file.new_path:
                        file_url = modified_file.new_path.replace('\\','/')
                    else:
                        file_url = modified_file.old_path.replace('\\','/')
                    for values in parsed_diff['added']:
                        lines.add(values[0])
                    
                    if (commit.hash == '48599be4e389124fa736272ca91ca77fefcba624') and (file_url == 'adanet/core/iteration_test.py'):
                        print(repoName,commit.hash, file_url,sorted(lines))
                        #file_url = modified_file.new_path.replace('\\','/')
                    #output_writer.writerow([repoName,commit.hash,file_url,sorted(lines)])
# Out:
# adanet
# adanet 48599be4e389124fa736272ca91ca77fefcba624 adanet/core/iteration_test.py [34, 35, 36, 37, 38, 39, 40, 47, 54, 55, 62, 69, 76, 83, 92, 153, 169, 328, 333, 340]

# %%
bug_fix_commit_lines = pd.read_csv('output_data/bug_fix_commits_lines.csv')

# %%
#bug_fix_commit_lines[bug_fix_commit_lines['bug_fix_lines']=='[]']
bug_fix_commit_lines = bug_fix_commit_lines[bug_fix_commit_lines.bug_fix_lines != '[]']

# %%
bug_fix_commit_lines[bug_fix_commit_lines['bug_fix_lines']=='[]']
# Out:
# Empty DataFrame
# Columns: [repoName, bug_fix_commit, bug_fix_file, bug_fix_lines]
# Index: []

# %%
Type1 = pd.read_csv('clone_data/dl_type1.csv')
Type2 = pd.read_csv('clone_data/dl_type2.csv')
Type3 = pd.read_csv('clone_data/dl_type3.csv')

# %%
Type1['clone_type']='Type 1'
Type2['clone_type']='Type 2'
Type3['clone_type']='Type 3'

# %%
clones = [Type1, Type2, Type3]
clones_df = pd.concat(clones)

# %%
def update_granularity(row):
    if 'function' in row['granularity']:
        return 'Function'
    elif 'block' in row['granularity']:
        return 'Block'

# %%
clones_df['granularity']=clones_df.apply(update_granularity, axis=1)

# %%
clones_df
# Out:
#               repoName  classid  \
# 0               adanet        1
# 1               adanet        1
# 2               adanet        2
# 3               adanet        2
# 4               adanet        3
# ...                ...      ...
# 33930  waifu2x-chainer        3
# 33931  waifu2x-chainer        3
# 33932  waifu2x-chainer        4
# 33933  waifu2x-chainer        4
# 33934  waifu2x-chainer        4
#
#                                                     file  startline  endline  \
# 0      ../clone_code/dl/adanet/adanet/ensemble/ensemb...         29       48
# 1      ../clone_code/dl/adanet/adanet/subnetwork/gene...         42       61
# 2      ../clone_code/dl/adanet/adanet/core/evaluator_...        121      126
# 3      ../clone_code/dl/adanet/adanet/core/evaluator_...        140      145
# 4      ../clone_code/dl/adanet/adanet/core/testing_ut...         43       49
# ...                                                  ...        ...      ...
# 33930  ../clone_code/dl/waifu2x-chainer/lib/srcnn.py....        116      128
# 33931  ../clone_code/dl/waifu2x-chainer/lib/srcnn.py....        147      159
# 33932  ../clone_code/dl/waifu2x-chainer/waifu2x.py.py...         17       33
# 33933  ../clone_code/dl/waifu2x-chainer/appendix/benc...         23       37
# 33934  ../clone_code/dl/waifu2x-chainer/appendix/benc...         38       51
#
#        pcid  similarity granularity clone_type
# 0        73         100       Block     Type 1
# 1       695         100       Block     Type 1
# 2       204         100       Block     Type 1
# 3       208         100       Block     Type 1
# 4       477         100       Block     Type 1
# ...     ...         ...         ...        ...
# 33930    35         100    Function     Type 3
# 33931    37         100    Function     Type 3
# 33932    51          71    Function     Type 3
# 33933    56          71    Function     Type 3
# 33934    57          71    Function     Type 3
#
# [50979 rows x 9 columns]

# %%
def update_file_url(row):
    repoName=row['repoName']
    return row['file'].replace('../clone_code/dl/'+repoName+'/','').replace('.pyindent','')

# %%
clones_df['file']=clones_df.apply(update_file_url, axis=1)

# %%
clones_df.to_csv('clone_data/dl_all_clones.csv')

# %%
clones_df_fct = clones_df[clones_df['granularity']=='Function']

# %%
clones_df_fct
# Out:
#               repoName  classid  \
# 27              adanet        1
# 28              adanet        1
# 29              adanet        2
# 30              adanet        2
# 31              adanet        3
# ...                ...      ...
# 33930  waifu2x-chainer        3
# 33931  waifu2x-chainer        3
# 33932  waifu2x-chainer        4
# 33933  waifu2x-chainer        4
# 33934  waifu2x-chainer        4
#
#                                                  file  startline  endline  \
# 27                       adanet/ensemble/ensembler.py         42       48
# 28                     adanet/subnetwork/generator.py         55       61
# 29                       adanet/core/testing_utils.py         42       49
# 30                adanet/subnetwork/generator_test.py         29       36
# 31     adanet/experimental/keras/model_search_test.py        114      128
# ...                                               ...        ...      ...
# 33930                                    lib/srcnn.py        116      128
# 33931                                    lib/srcnn.py        147      159
# 33932                                      waifu2x.py         17       33
# 33933                           appendix/benchmark.py         23       37
# 33934                           appendix/benchmark.py         38       51
#
#        pcid  similarity granularity clone_type
# 27       41         100    Function     Type 1
# 28      299         100    Function     Type 1
# 29      216         100    Function     Type 1
# 30      284         100    Function     Type 1
# 31      342         100    Function     Type 1
# ...     ...         ...         ...        ...
# 33930    35         100    Function     Type 3
# 33931    37         100    Function     Type 3
# 33932    51          71    Function     Type 3
# 33933    56          71    Function     Type 3
# 33934    57          71    Function     Type 3
#
# [25348 rows x 9 columns]

# %%
clones_by_commits = pd.read_csv('output_data/clones.csv')

# %%
clones_by_commits['granularity']=clones_by_commits.apply(update_granularity, axis=1)

# %%
clones_by_commits_fct = clones_by_commits[clones_by_commits['granularity']=='Function']

# %%
clones_by_commits_fct[clones_by_commits_fct['file']=='adanet/core/testing_utils.py']
# Out:
#       repository                                 commit_id  classid  nlines  \
# 0         adanet  001d2986a1311ed9f36d59bd49c3e97abe6f2491        1       6
# 14        adanet  003a9527c0c40f06e574ca16b7d2245b1181bc09        2       6
# 27        adanet  01a911a0cfead87b1aa0aa836cbef6ba4ffe307b        1       6
# 28        adanet  01a911a0cfead87b1aa0aa836cbef6ba4ffe307b        2       5
# 29        adanet  01a911a0cfead87b1aa0aa836cbef6ba4ffe307b        2       5
# ...          ...                                       ...      ...     ...
# 88775     adanet  ff6ab1eee6b93b912b3b020957c51b83b8da4b95       23       6
# 88777     adanet  ff6ab1eee6b93b912b3b020957c51b83b8da4b95       24      25
# 88778     adanet  ff6ab1eee6b93b912b3b020957c51b83b8da4b95       24      25
# 88848     adanet  ffa05d2e79960b8b7a3ebd99958dcb2129eaa7cf        5       5
# 88850     adanet  ffa05d2e79960b8b7a3ebd99958dcb2129eaa7cf        5       5
#
#        nclones                          file  startline  endline  pcid  \
# 0            2  adanet/core/testing_utils.py         44       51   224
# 14           2  adanet/core/testing_utils.py         37       44   173
# 27           2  adanet/core/testing_utils.py         33       40   170
# 28           2  adanet/core/testing_utils.py        241      245   179
# 29           2  adanet/core/testing_utils.py        249      253   180
# ...        ...                           ...        ...      ...   ...
# 88775        2  adanet/core/testing_utils.py         44       51   199
# 88777        2  adanet/core/testing_utils.py        339      390   216
# 88778        2  adanet/core/testing_utils.py        391      436   217
# 88848        6  adanet/core/testing_utils.py        235      239   162
# 88850        6  adanet/core/testing_utils.py        243      247   163
#
#        similarity granularity clone_type
# 0             100    Function     Type 1
# 14            100    Function     Type 1
# 27            100    Function     Type 1
# 28            100    Function     Type 1
# 29            100    Function     Type 1
# ...           ...         ...        ...
# 88775         100    Function     Type 3
# 88777          75    Function     Type 3
# 88778          75    Function     Type 3
# 88848          80    Function     Type 3
# 88850          80    Function     Type 3
#
# [3146 rows x 12 columns]

# %% [markdown]
# ### Let's clean code clones types

# %%
type1_2= [clones_by_commits_fct[clones_by_commits_fct['clone_type']=='Type 1'], clones_by_commits_fct[clones_by_commits_fct['clone_type']=='Type 2']]
type1_from_type2 = pd.concat(type1_2)

# %%
Type2=type1_from_type2.drop_duplicates(subset=['repository','commit_id','nlines','nclones','file','startline','endline','pcid','similarity','granularity'], keep='last', inplace=False)

# %%
type2_3= [clones_by_commits_fct[clones_by_commits_fct['clone_type']=='Type 2'], clones_by_commits_fct[clones_by_commits_fct['clone_type']=='Type 3']]
type2_from_type3 = pd.concat(type2_3)

# %%
Type3=type2_from_type3.drop_duplicates(subset=['repository','commit_id','nlines','nclones','file','startline','endline','pcid','similarity','granularity'], keep='last', inplace=False)

# %%
Type3=Type3[Type3['clone_type']=='Type 3']

# %%
Type2=Type2[Type2['clone_type']=='Type 2']

# %%
Type1=clones_by_commits_fct[clones_by_commits_fct['clone_type']=='Type 1']

# %%
Types = [Type1, Type2, Type3]
all_clones_fct = pd.concat(Types)

# %%
all_clones_fct.to_csv('output_data/dl_all_clones_clean_by_commits.csv', index=False)

# %%
all_clones_fct = pd.read_csv('output_data/dl_all_clones_clean_by_commits.csv')

# %%
all_clones_fct
# Out:
#        repository                                 commit_id  classid  nlines  \
# 0          adanet  001d2986a1311ed9f36d59bd49c3e97abe6f2491        1       6
# 1          adanet  001d2986a1311ed9f36d59bd49c3e97abe6f2491        1       6
# 2          adanet  001d2986a1311ed9f36d59bd49c3e97abe6f2491        2       6
# 3          adanet  001d2986a1311ed9f36d59bd49c3e97abe6f2491        2       6
# 4          adanet  001d2986a1311ed9f36d59bd49c3e97abe6f2491        3       5
# ...           ...                                       ...      ...     ...
# 139030    ranking  ffa03c7fb99cb48f591637cbfcece79daaad83a9       32      15
# 139031    ranking  ffa03c7fb99cb48f591637cbfcece79daaad83a9       33      40
# 139032    ranking  ffa03c7fb99cb48f591637cbfcece79daaad83a9       33      40
# 139033    ranking  ffa03c7fb99cb48f591637cbfcece79daaad83a9       34      14
# 139034    ranking  ffa03c7fb99cb48f591637cbfcece79daaad83a9       34      14
#
#         nclones                                       file  startline  \
# 0             2               adanet/core/testing_utils.py         44
# 1             2        adanet/subnetwork/generator_test.py         29
# 2             2               adanet/ensemble/ensembler.py         40
# 3             2             adanet/subnetwork/generator.py         55
# 4             2                  adanet/examples/nasnet.py        232
# ...         ...                                        ...        ...
# 139030        3  tensorflow_ranking/python/metrics_test.py        250
# 139031        2  tensorflow_ranking/python/metrics_test.py        389
# 139032        2  tensorflow_ranking/python/metrics_test.py        578
# 139033        2    tensorflow_ranking/python/utils_test.py         32
# 139034        2    tensorflow_ranking/python/utils_test.py        143
#
#         endline  pcid  similarity granularity clone_type
# 0            51   224         100    Function     Type 1
# 1            36   344         100    Function     Type 1
# 2            46   294         100    Function     Type 1
# 3            61   335         100    Function     Type 1
# 4           236   320         100    Function     Type 1
# ...         ...   ...         ...         ...        ...
# 139030      261   207          73    Function     Type 3
# 139031      427   213          70    Function     Type 3
# 139032      614   219          70    Function     Type 3
# 139033       39   254          71    Function     Type 3
# 139034      152   261          71    Function     Type 3
#
# [139035 rows x 12 columns]

# %%
bug_fix_commit_lines
# Out:
#     repoName                            bug_fix_commit  \
# 0     adanet  28f70c3980d4c57cac2dba0a8269284f82f65584
# 1     adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# 2     adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# 3     adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# 4     adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# ..       ...                                       ...
# 730  ranking  b859d5f5e3ba8eef2725cc2a71eca708c7cb7993
# 731  ranking  7dbfc71cc427e3bd7e97e083a9abeb1ba1bf44bf
# 732  ranking  534ee5ab3b17e65570c81be3956e5ede5dd780a8
# 733  ranking  534ee5ab3b17e65570c81be3956e5ede5dd780a8
# 734  ranking  534ee5ab3b17e65570c81be3956e5ede5dd780a8
#
#                                       bug_fix_file  \
# 0                              adanet/evaluator.py
# 1                         adanet/core/candidate.py
# 2                    adanet/core/candidate_test.py
# 3                    adanet/core/estimator_test.py
# 4                         adanet/core/iteration.py
# ..                                             ...
# 730              tensorflow_ranking/python/data.py
# 731           tensorflow_ranking/python/metrics.py
# 732     tensorflow_ranking/python/keras/feature.py
# 733       tensorflow_ranking/python/keras/model.py
# 734  tensorflow_ranking/python/keras/model_test.py
#
#                                          bug_fix_lines
# 0    [78, 79, 80, 81, 82, 83, 91, 95, 97, 98, 101, ...
# 1    [26, 27, 106, 107, 117, 118, 139, 150, 151, 15...
# 2    [68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 7...
# 3                                      [418, 846, 848]
# 4                                      [149, 165, 209]
# ..                                                 ...
# 730                                         [801, 802]
# 731                              [41, 47, 50, 84, 354]
# 732                              [74, 75, 84, 85, 107]
# 733           [23, 24, 25, 26, 27, 28, 46, 47, 56, 57]
# 734  [184, 185, 186, 187, 188, 189, 190, 191, 192, ...
#
# [686 rows x 4 columns]

# %% [markdown]
# ## Merge

# %%
result = pd.merge(bug_fix_commit_lines, all_clones_fct.rename(columns={'repository':'repoName', 'commit_id':'bug_fix_commit', 'file':'bug_fix_file'}), how='left', on=['repoName', 'bug_fix_commit', 'bug_fix_file'])

# %%
result_withoutnan = result.dropna()

# %%
def lines_intersects_with_clone_code(lines, start_line, end_line):
    print(lines, start_line,end_line)
    print(type(lines), type(start_line),type(end_line))
    found = list(filter(lambda x: start_line <= x <= end_line, lines))
    print(found)
    if len(found)>0:
        return True
    else:
        return False

# %%
int('1')
# Out:
# 1

# %%
global i
i=0 #1341

# %%
def get_clone_code_flag(raw):
    lines=raw['bug_fix_lines']
    buggy_file=raw['bug_fix_file']
    start_line = raw['startline']
    end_line = raw['endline']
    global i
    i=i+1
    print(i)
    print('startline ----->',start_line)
    print('endline ----->',end_line)
    if isNaN(start_line) or  isNaN(end_line):
        print('not clone')
        return False
    else:
        if lines_intersects_with_clone_code(transform_lines_to_set(lines), int(start_line), int(end_line)):
            print('yes clone')
            return True
        else:
            return False

# %%
def isNaN(string):
    return string != string

# %%
def transform_lines_to_set(lines):
    lines_list=set()
    print(lines)
    for i in lines.split(','):
        lines_list.add(int(i.replace('[','').replace(']','')))
    return lines_list

# %%
result_withoutnan[result_withoutnan['bug_fix_lines']=='[]']
# Out:
#      repoName                            bug_fix_commit  \
# 34     adanet  48599be4e389124fa736272ca91ca77fefcba624
# 35     adanet  48599be4e389124fa736272ca91ca77fefcba624
# 36     adanet  48599be4e389124fa736272ca91ca77fefcba624
# 37     adanet  48599be4e389124fa736272ca91ca77fefcba624
# 38     adanet  48599be4e389124fa736272ca91ca77fefcba624
# ...       ...                                       ...
# 1859  ranking  7de1bd2d366d942c0acaabc91876035cc1d9c3f0
# 1860  ranking  7de1bd2d366d942c0acaabc91876035cc1d9c3f0
# 1861  ranking  7de1bd2d366d942c0acaabc91876035cc1d9c3f0
# 1862  ranking  7de1bd2d366d942c0acaabc91876035cc1d9c3f0
# 1863  ranking  7de1bd2d366d942c0acaabc91876035cc1d9c3f0
#
#                              bug_fix_file bug_fix_lines  classid  nlines  \
# 34           adanet/core/testing_utils.py            []      1.0     5.0
# 35           adanet/core/testing_utils.py            []      1.0     5.0
# 36           adanet/core/testing_utils.py            []      5.0     5.0
# 37           adanet/core/testing_utils.py            []      5.0     5.0
# 38           adanet/core/testing_utils.py            []      9.0     5.0
# ...                                   ...           ...      ...     ...
# 1859  tensorflow_ranking/python/losses.py            []      8.0    14.0
# 1860  tensorflow_ranking/python/losses.py            []      8.0    14.0
# 1861  tensorflow_ranking/python/losses.py            []      8.0    14.0
# 1862  tensorflow_ranking/python/losses.py            []      9.0    10.0
# 1863  tensorflow_ranking/python/losses.py            []      9.0    10.0
#
#       nclones  startline  endline   pcid  similarity granularity clone_type
# 34        2.0      235.0    239.0  166.0       100.0    Function     Type 1
# 35        2.0      243.0    247.0  167.0       100.0    Function     Type 1
# 36        2.0      235.0    239.0  166.0       100.0    Function     Type 2
# 37        2.0      243.0    247.0  167.0       100.0    Function     Type 2
# 38        4.0      235.0    239.0  166.0        80.0    Function     Type 3
# ...       ...        ...      ...    ...         ...         ...        ...
# 1859     10.0      797.0    831.0   61.0        71.0    Function     Type 3
# 1860     10.0      946.0    983.0   68.0        71.0    Function     Type 3
# 1861     10.0     1207.0   1239.0   78.0        71.0    Function     Type 3
# 1862      2.0     1009.0   1019.0   71.0       100.0    Function     Type 3
# 1863      2.0     1056.0   1066.0   73.0       100.0    Function     Type 3
#
# [71 rows x 13 columns]

# %%
result_withoutnan['is_clone_code']=result_withoutnan.apply(get_clone_code_flag, axis=1)

# %%
bug_fix_with_clones=result_withoutnan.drop_duplicates(subset=['repoName','bug_fix_commit','bug_fix_file','bug_fix_lines','granularity','clone_type','is_clone_code'], keep='last', inplace=False)

# %%
result
# Out:
#      repoName                            bug_fix_commit  \
# 0      adanet  28f70c3980d4c57cac2dba0a8269284f82f65584
# 1      adanet  28f70c3980d4c57cac2dba0a8269284f82f65584
# 2      adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# 3      adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# 4      adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# ...       ...                                       ...
# 1885  ranking  7dbfc71cc427e3bd7e97e083a9abeb1ba1bf44bf
# 1886  ranking  7dbfc71cc427e3bd7e97e083a9abeb1ba1bf44bf
# 1887  ranking  534ee5ab3b17e65570c81be3956e5ede5dd780a8
# 1888  ranking  534ee5ab3b17e65570c81be3956e5ede5dd780a8
# 1889  ranking  534ee5ab3b17e65570c81be3956e5ede5dd780a8
#
#                                        bug_fix_file  \
# 0                               adanet/evaluator.py
# 1                               adanet/evaluator.py
# 2                          adanet/core/candidate.py
# 3                     adanet/core/candidate_test.py
# 4                     adanet/core/candidate_test.py
# ...                                             ...
# 1885           tensorflow_ranking/python/metrics.py
# 1886           tensorflow_ranking/python/metrics.py
# 1887     tensorflow_ranking/python/keras/feature.py
# 1888       tensorflow_ranking/python/keras/model.py
# 1889  tensorflow_ranking/python/keras/model_test.py
#
#                                           bug_fix_lines  classid  nlines  \
# 0     [78, 79, 80, 81, 82, 83, 91, 95, 97, 98, 101, ...      2.0     6.0
# 1     [78, 79, 80, 81, 82, 83, 91, 95, 97, 98, 101, ...      6.0     6.0
# 2     [26, 27, 106, 107, 117, 118, 139, 150, 151, 15...      NaN     NaN
# 3     [68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 7...      1.0    11.0
# 4     [68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 7...      1.0    11.0
# ...                                                 ...      ...     ...
# 1885                              [41, 47, 50, 84, 354]     28.0    18.0
# 1886                              [41, 47, 50, 84, 354]     28.0    18.0
# 1887                              [74, 75, 84, 85, 107]      NaN     NaN
# 1888           [23, 24, 25, 26, 27, 28, 46, 47, 56, 57]      NaN     NaN
# 1889  [184, 185, 186, 187, 188, 189, 190, 191, 192, ...      NaN     NaN
#
#       nclones  startline  endline   pcid  similarity granularity clone_type  \
# 0         2.0       30.0     48.0   44.0       100.0    Function     Type 2
# 1         2.0       30.0     48.0   44.0       100.0    Function     Type 3
# 2         NaN        NaN      NaN    NaN         NaN         NaN        NaN
# 3         4.0       60.0     65.0   24.0        72.0    Function     Type 3
# 4         4.0      179.0    184.0   26.0        72.0    Function     Type 3
# ...       ...        ...      ...    ...         ...         ...        ...
# 1885      2.0      288.0    321.0  168.0        78.0    Function     Type 3
# 1886      2.0      322.0    352.0  169.0        78.0    Function     Type 3
# 1887      NaN        NaN      NaN    NaN         NaN         NaN        NaN
# 1888      NaN        NaN      NaN    NaN         NaN         NaN        NaN
# 1889      NaN        NaN      NaN    NaN         NaN         NaN        NaN
#
#       is_clone_code
# 0              True
# 1              True
# 2             False
# 3              True
# 4              True
# ...             ...
# 1885           True
# 1886           True
# 1887          False
# 1888          False
# 1889          False
#
# [1890 rows x 14 columns]

# %%
result.to_csv('output_data/bug_fix_commits_lines_flag_clone.csv', index=False)

# %%
1466+424
# Out:
# 1890

# %%
1466/1890
# Out:
# 0.7756613756613756

# %%
424/1890
# Out:
# 0.22433862433862434

# %%
bug_fix_commit_lines
# Out:
#     repoName                            bug_fix_commit  \
# 0     adanet  28f70c3980d4c57cac2dba0a8269284f82f65584
# 1     adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# 2     adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# 3     adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# 4     adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3
# ..       ...                                       ...
# 730  ranking  b859d5f5e3ba8eef2725cc2a71eca708c7cb7993
# 731  ranking  7dbfc71cc427e3bd7e97e083a9abeb1ba1bf44bf
# 732  ranking  534ee5ab3b17e65570c81be3956e5ede5dd780a8
# 733  ranking  534ee5ab3b17e65570c81be3956e5ede5dd780a8
# 734  ranking  534ee5ab3b17e65570c81be3956e5ede5dd780a8
#
#                                       bug_fix_file  \
# 0                              adanet/evaluator.py
# 1                         adanet/core/candidate.py
# 2                    adanet/core/candidate_test.py
# 3                    adanet/core/estimator_test.py
# 4                         adanet/core/iteration.py
# ..                                             ...
# 730              tensorflow_ranking/python/data.py
# 731           tensorflow_ranking/python/metrics.py
# 732     tensorflow_ranking/python/keras/feature.py
# 733       tensorflow_ranking/python/keras/model.py
# 734  tensorflow_ranking/python/keras/model_test.py
#
#                                          bug_fix_lines
# 0    [78, 79, 80, 81, 82, 83, 91, 95, 97, 98, 101, ...
# 1    [26, 27, 106, 107, 117, 118, 139, 150, 151, 15...
# 2    [68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 7...
# 3                                      [418, 846, 848]
# 4                                      [149, 165, 209]
# ..                                                 ...
# 730                                         [801, 802]
# 731                              [41, 47, 50, 84, 354]
# 732                              [74, 75, 84, 85, 107]
# 733           [23, 24, 25, 26, 27, 28, 46, 47, 56, 57]
# 734  [184, 185, 186, 187, 188, 189, 190, 191, 192, ...
#
# [686 rows x 4 columns]

# %% [markdown]
# ## First analysis: Average bug fix on code clones

# %%
result['nb_clone_code']=1

# %%
result_by_clone_type = result.groupby(['repoName','is_clone_code']).agg({'nb_clone_code':'count'}).reset_index()
result_by_project=result_by_clone_type.groupby(['repoName','is_clone_code']).agg({'nb_clone_code':'sum'}).reset_index()

# %%
result_by_clone_type
# Out:
#               repoName  is_clone_code  nb_clone_code
# 0             BerryNet          False              7
# 1             BerryNet           True             60
# 2              DeepCTR          False            120
# 3              DeepCTR           True            366
# 4               adanet          False            252
# 5               adanet           True            831
# 6   keras-applications          False             17
# 7   keras-applications           True             40
# 8               nn-wtf          False             17
# 9               nn-wtf           True             17
# 10             ranking          False             11
# 11             ranking           True            152

# %%
152/(152+11)
# Out:
# 0.9325153374233128

# %%
(89.6+75.31+76.73+70.18+50+93.25)/6
# Out:
# 75.845

# %%
result_cloned = result[result['is_clone_code']==True]

# %%
result_cloned_by_clone_type = result.groupby(['repoName','clone_type']).agg({'nb_clone_code':'count'}).reset_index()

# %%
result_cloned_by_proj = result_cloned_by_clone_type.groupby(['repoName']).agg({'nb_clone_code':'sum'}).reset_index()

# %%
result_cloned_by_proj=result_cloned_by_proj.rename(columns={"nb_clone_code": "total"})

# %%
result_cloned_by_clone_type = pd.merge(result_cloned_by_clone_type,result_cloned_by_proj[['repoName','total']],how='left', on=['repoName'])
result_cloned_by_clone_type['percentage']=(result_cloned_by_clone_type['nb_clone_code']/result_cloned_by_clone_type['total'])*100

# %%
result_cloned_by_clone_type
# Out:
#               repoName clone_type  nb_clone_code  total  percentage
# 0             BerryNet     Type 1             10     60   16.666667
# 1             BerryNet     Type 2             13     60   21.666667
# 2             BerryNet     Type 3             37     60   61.666667
# 3              DeepCTR     Type 1             20    366    5.464481
# 4              DeepCTR     Type 2             42    366   11.475410
# 5              DeepCTR     Type 3            304    366   83.060109
# 6               adanet     Type 1             48    831    5.776173
# 7               adanet     Type 2            170    831   20.457280
# 8               adanet     Type 3            613    831   73.766546
# 9   keras-applications     Type 2             14     40   35.000000
# 10  keras-applications     Type 3             26     40   65.000000
# 11              nn-wtf     Type 3             17     17  100.000000
# 12             ranking     Type 1             10    152    6.578947
# 13             ranking     Type 2             43    152   28.289474
# 14             ranking     Type 3             99    152   65.131579

# %%
result_cloned_by_clone_type[result_cloned_by_clone_type['clone_type']=='Type 1'].percentage.sum()/6
# Out:
# 5.747711365767202

# %%
result_cloned_by_clone_type[result_cloned_by_clone_type['clone_type']=='Type 2'].percentage.sum()/6
# Out:
# 19.481471762003498

# %%
result_cloned_by_clone_type[result_cloned_by_clone_type['clone_type']=='Type 3'].percentage.sum()/6
# Out:
# 74.7708168722293

# %%
5.75+19.48+74.77
# Out:
# 100.0

# %%
df = pd.DataFrame()
df['percentage of buggy clone'] = pd.Series([5.75,19.48,74.77 ])
df['Clone Type'] = pd.Series(['Type 1', 'Type 2', 'Type 3'])

# %%
sns.barplot(x='Clone Type',y='percentage of buggy clone',data=df)

# %% [markdown]
# ## Third Analysis: How much fragments are arised from Clone Type How much bug fix occured on each type

# %%
clone_buggy = pd.merge(all_clones_fct.rename(columns={'repository':'repoName', 'commit_id':'bug_fix_commit', 'file':'bug_fix_file'}),bug_fix_commit_lines, how='left', on=['repoName', 'bug_fix_commit', 'bug_fix_file'])

# %%
def buggy_or_not(row):
    if row['bug_fix_lines'] is np.NaN:
        return 'non buggy'
    else:
        return 'buggy'

# %%
clone_buggy['buggy_or_not']=clone_buggy.apply(buggy_or_not, axis=1)

# %%
clone_buggy[clone_buggy['buggy_or_not']=='buggy']
# Out:
#        repoName                            bug_fix_commit  classid  nlines  \
# 128      adanet  0953ca2e5690eb258a8787435e498fa6917238b6        1       6
# 129      adanet  0953ca2e5690eb258a8787435e498fa6917238b6        1       6
# 130      adanet  0953ca2e5690eb258a8787435e498fa6917238b6        2       5
# 131      adanet  0953ca2e5690eb258a8787435e498fa6917238b6        2       5
# 208      adanet  0ce83c23a8bb71c75ad31fb33b6e98de6caf83d3        1       5
# ...         ...                                       ...      ...     ...
# 134979  ranking  b56ff127f00976556ab95216426191b0768e74ee        3      19
# 134980  ranking  b56ff127f00976556ab95216426191b0768e74ee        4      19
# 134981  ranking  b56ff127f00976556ab95216426191b0768e74ee        4      19
# 138739  ranking  fd3a5c54eb61292c1f21ed93c5546ca5de207cb8        1      26
# 138740  ranking  fd3a5c54eb61292c1f21ed93c5546ca5de207cb8        1      26
#
#         nclones                              bug_fix_file  startline  endline  \
# 128           2  adanet/core/subnetwork/generator_test.py         27       34
# 129           2              adanet/core/testing_utils.py         28       35
# 130           2              adanet/core/testing_utils.py        236      240
# 131           2              adanet/core/testing_utils.py        244      248
# 208           2              adanet/core/testing_utils.py        246      250
# ...         ...                                       ...        ...      ...
# 134979        3       tensorflow_ranking/python/losses.py        681      725
# 134980        2       tensorflow_ranking/python/losses.py        784      823
# 134981        2       tensorflow_ranking/python/losses.py        824      861
# 138739        2    tensorflow_ranking/python/data_test.py        124      149
# 138740        2    tensorflow_ranking/python/data_test.py        150      173
#
#         pcid  similarity granularity clone_type  \
# 128      116         100    Function     Type 1
# 129      153         100    Function     Type 1
# 130      162         100    Function     Type 1
# 131      163         100    Function     Type 1
# 208      166         100    Function     Type 1
# ...      ...         ...         ...        ...
# 134979    42          70    Function     Type 3
# 134980    45          80    Function     Type 3
# 134981    46          80    Function     Type 3
# 138739     3          70    Function     Type 3
# 138740     4          70    Function     Type 3
#
#                                             bug_fix_lines buggy_or_not
# 128     [1, 23, 27, 28, 29, 30, 31, 32, 33, 34, 35, 39...        buggy
# 129                  [23, 24, 48, 62, 103, 104, 108, 119]        buggy
# 130                  [23, 24, 48, 62, 103, 104, 108, 119]        buggy
# 131                  [23, 24, 48, 62, 103, 104, 108, 119]        buggy
# 208                             [56, 57, 75, 88, 89, 128]        buggy
# ...                                                   ...          ...
# 134979                                              [481]        buggy
# 134980                                              [481]        buggy
# 134981                                              [481]        buggy
# 138739                     [139, 144, 148, 172, 229, 266]        buggy
# 138740                     [139, 144, 148, 172, 229, 266]        buggy
#
# [1466 rows x 14 columns]

# %%
clone_buggy_per_project = clone_buggy.groupby(['repoName','clone_type','buggy_or_not']).agg({'nclones':'sum'}).reset_index()

# %%
clone_buggy_per_project_size = clone_buggy_per_project.groupby(['repoName','clone_type']).agg({'nclones':'sum'}).reset_index()

# %%
clone_buggy_per_project_size=clone_buggy_per_project_size.rename(columns={"nclones": "total_fragments"})

# %%
clone_buggy_per_project_size
# Out:
#               repoName clone_type  total_fragments
# 0             BerryNet     Type 1            37175
# 1             BerryNet     Type 2            48649
# 2             BerryNet     Type 3           114586
# 3              DeepCTR     Type 1             1359
# 4              DeepCTR     Type 2             2320
# 5              DeepCTR     Type 3            40137
# 6               adanet     Type 1             8314
# 7               adanet     Type 2            21537
# 8               adanet     Type 3           120537
# 9   keras-applications     Type 2             1110
# 10  keras-applications     Type 3             6285
# 11              nn-wtf     Type 2              432
# 12              nn-wtf     Type 3            10013
# 13             ranking     Type 1             2751
# 14             ranking     Type 2            13704
# 15             ranking     Type 3            63694

# %%
clone_buggy_per_project = pd.merge(clone_buggy_per_project,clone_buggy_per_project_size[['repoName','clone_type','total_fragments']],how='left', on=['repoName','clone_type'])

# %%
clone_buggy_per_project['percentage']=(clone_buggy_per_project['nclones']/clone_buggy_per_project['total_fragments'])*100

# %%
buggy=clone_buggy_per_project[clone_buggy_per_project['buggy_or_not']=='buggy']

# %%
buggy[buggy['clone_type']=='Type 3'].percentage.sum()/6
# Out:
# 2.119024819922681

# %%
buggy
# Out:
#               repoName clone_type buggy_or_not  nclones  total_fragments  \
# 0             BerryNet     Type 1        buggy       20            37175
# 2             BerryNet     Type 2        buggy       29            48649
# 4             BerryNet     Type 3        buggy      130           114586
# 6              DeepCTR     Type 1        buggy       64             1359
# 8              DeepCTR     Type 2        buggy      111             2320
# 10             DeepCTR     Type 3        buggy     2188            40137
# 12              adanet     Type 1        buggy       96             8314
# 14              adanet     Type 2        buggy      401            21537
# 16              adanet     Type 3        buggy     2321           120537
# 18  keras-applications     Type 2        buggy       40             1110
# 20  keras-applications     Type 3        buggy      228             6285
# 23              nn-wtf     Type 3        buggy      107            10013
# 25             ranking     Type 1        buggy       26             2751
# 27             ranking     Type 2        buggy      134            13704
# 29             ranking     Type 3        buggy      336            63694
#
#     percentage
# 0     0.053800
# 2     0.059611
# 4     0.113452
# 6     4.709345
# 8     4.784483
# 10    5.451329
# 12    1.154679
# 14    1.861912
# 16    1.925550
# 18    3.603604
# 20    3.627685
# 23    1.068611
# 25    0.945111
# 27    0.977817
# 29    0.527522

# %%
Type 1: 1.71 of clone fragments are from Type 1 and buggy
Type 2: 2.26 of clone fragments are from Type 2 and buggy
Type 3: 2.11 of clone fragments are from Type 3 and buggy

# %%
#sns.set_style("whitegrid")
plt.figure(figsize=(5,8))
g = sns.boxplot(x="clone_type", y="percentage", data=clone_buggy_per_project,hue="buggy_or_not",showfliers=False)
#g.set_yscale("log")
g.set(xlabel=' ', ylabel='Percentage of Number of fragments')
#plt.title('Time consumed to fix bugs')
# Out:
# [Text(0, 0.5, 'Percentage of Number of fragments'), Text(0.5, 0, ' ')]

# %%
df = pd.DataFrame()
df['percentage of buggy fragments'] = pd.Series([1.71,2.26,2.11 ])
df['Clone Type'] = pd.Series(['Type 1', 'Type 2', 'Type 3'])

# %%
sns.barplot(x='Clone Type',y='percentage of buggy fragments',data=df)
