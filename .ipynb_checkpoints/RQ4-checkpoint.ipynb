# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# %%
dl_taxonomy=pd.read_csv('manual_analysis/labeled_phases.csv')

# %%
dl_taxonomy
# Out:
#     repoName  classid  g  similarity  \
# 0   BerryNet       25  f         100
# 1   BerryNet       13  f         100
# 2   BerryNet       20  f         100
# 3   BerryNet       26  f         100
# 4   BerryNet       27  f         100
# ..       ...      ... ..         ...
# 92   ranking        6  f          81
# 93   ranking        7  f         100
# 94   ranking        8  f         100
# 95   ranking        9  f          78
# 96   ranking       30  f          83
#
#                                                 files  \
# 0   {'../clone_code/dl/BerryNet/berrynet/engine/tf...
# 1   {'../clone_code/dl/BerryNet/inference/movidius...
# 2   {'../clone_code/dl/BerryNet/inference/darkflow...
# 3   ['../clone_code/dl/BerryNet/berrynet/service/t...
# 4   ['../clone_code/dl/BerryNet/berrynet/service/t...
# ..                                                ...
# 92  {'../clone_code/dl/ranking/tensorflow_ranking/...
# 93  ['../clone_code/dl/ranking/tensorflow_ranking/...
# 94  ['../clone_code/dl/ranking/tensorflow_ranking/...
# 95  {'../clone_code/dl/ranking/tensorflow_ranking/...
# 96  {'../clone_code/dl/ranking/tensorflow_ranking/...
#
#                        startlines                       endlines  nb_fragment  \
# 0                      {102, 183}                     {107, 188}            2
# 1                       {176, 92}                     {187, 103}            2
# 2                        {66, 70}                       {97, 93}            2
# 3                        [32, 37]                       [41, 36]            2
# 4            [36, 37, 49, 84, 85]           [41, 42, 54, 89, 90]            5
# ..                            ...                            ...          ...
# 92      {131, 142, 111, 151, 120}      {130, 141, 150, 119, 159}            5
# 93  [161, 35, 138, 281, 28, 1087]  [1090, 164, 38, 141, 284, 31]            6
# 94                    [1091, 142]                    [1098, 149]            2
# 95                     {288, 322}                     {352, 321}            2
# 96                     {411, 597}                     {432, 603}            2
#
#    granularity clone_type   project_type  category  locc  clone category  \
# 0     Function     type 1  Deep Learning         0     6       Same file
# 1     Function     type 1  Deep Learning         1    12  Same directory
# 2     Function     type 1  Deep Learning         1    28  Same directory
# 3     Function     type 2  Deep Learning         1     5  Same directory
# 4     Function     type 2  Deep Learning         1     6  Same directory
# ..         ...        ...            ...       ...   ...             ...
# 92    Function     type 3  Deep Learning         0    11       Same file
# 93    Function     type 2  Deep Learning         1     4  Same directory
# 94    Function     type 2  Deep Learning         1     8  Same directory
# 95    Function     type 3  Deep Learning         0    34       Same file
# 96    Function     type 3  Deep Learning         0    22       Same file
#
#                dl_phase                                        sub_class  \
# 0       data collection                                       load label
# 1        model training                measure the accuracy of the model
# 2   data postprocessing                              object localization
# 3    model construction  model parameters/hyperparameters initialization
# 4    model construction  model parameters/hyperparameters initialization
# ..                  ...                                              ...
# 92     model evaluation             model performance metric computation
# 93   model construction  model parameters/hyperparameters initialization
# 94     model evaluation             model performance metric computation
# 95     model evaluation             model performance metric computation
# 96     model evaluation             model performance metric computation
#
#                                              comments
# 0                               get labels from file
# 1   iou (intersection over union) metric measure t...
# 2   draw bounding boxes on an image from inference...
# 3                                init classif service
# 4           initializing model parameters with config
# ..                                                ...
# 92  precision cummulative gain mean_reciprocal_ran...
# 93                                       set up model
# 94                         check metric against value
# 95  normalized_discounted_cumulative_gain discount...
# 96                                        eval metric
#
# [97 rows x 17 columns]

# %%
dl_taxonomy['occs']=1

# %%
dl_taxonomy_category = dl_taxonomy.groupby(['dl_phase', 'sub_class']).agg({'occs': 'sum'})
# Change: groupby  and divide by sum
dl_taxonomy_sub_cat = dl_taxonomy_category.groupby(level=0).apply(lambda x:
                                                 100 * x / float(x.sum()))

# %%
dl_taxonomy_category
# Out:
#                                                                        occs
# dl_phase              sub_class
# configuration         hardware requirements                               1
# data collection       load data                                           4
#                       load label                                          1
# data postprocessing   compute output shape                                1
#                       object localization                                 3
#                       process output                                      3
#                       set shape of output data                            1
# data preprocessing    apply data augmentation                             1
#                       data normalization                                  2
#                       get batches of data                                 1
#                       get numerical feature columns                       2
#                       parse arguments                                     1
#                       prepare tensor                                      2
#                       process input                                       3
#                       resize image                                        1
#                       set shape of input data                             2
#                       set type of input data                              1
#                       setting format input data                           1
#                       split data                                          1
# hyperparameter tuning hyperparameter tuning                               1
# inference             inference                                           2
# model construction    Model component format verification                 1
#                       activation function call                            1
#                       build model                                         1
#                       build one subnetwork                                1
#                       compute model outputs                               1
#                       init evaluation metrics                             1
#                       initialize model graph                              1
#                       initialize model output                             1
#                       initialize weights                                  1
#                       layer construction                                  2
#                       model architecture instantiation                    2
#                       model parameters/hyperparameters initialization    22
# model evaluation      model performance metric computation                8
#                       predict test data                                   1
# model training        compute loss                                        5
#                       get pooling info                                    1
#                       measure the accuracy of the model                   1
#                       model training                                      3
#                       one model step training                             5
#                       training precedure                                  1
#                       weight normalization                                2

# %%
dl_taxonomy_sub_cat
# Out:
#                                                                              occs
# dl_phase              sub_class
# configuration         hardware requirements                            100.000000
# data collection       load data                                         80.000000
#                       load label                                        20.000000
# data postprocessing   compute output shape                              12.500000
#                       object localization                               37.500000
#                       process output                                    37.500000
#                       set shape of output data                          12.500000
# data preprocessing    apply data augmentation                            5.555556
#                       data normalization                                11.111111
#                       get batches of data                                5.555556
#                       get numerical feature columns                     11.111111
#                       parse arguments                                    5.555556
#                       prepare tensor                                    11.111111
#                       process input                                     16.666667
#                       resize image                                       5.555556
#                       set shape of input data                           11.111111
#                       set type of input data                             5.555556
#                       setting format input data                          5.555556
#                       split data                                         5.555556
# hyperparameter tuning hyperparameter tuning                            100.000000
# inference             inference                                        100.000000
# model construction    Model component format verification                2.857143
#                       activation function call                           2.857143
#                       build model                                        2.857143
#                       build one subnetwork                               2.857143
#                       compute model outputs                              2.857143
#                       init evaluation metrics                            2.857143
#                       initialize model graph                             2.857143
#                       initialize model output                            2.857143
#                       initialize weights                                 2.857143
#                       layer construction                                 5.714286
#                       model architecture instantiation                   5.714286
#                       model parameters/hyperparameters initialization   62.857143
# model evaluation      model performance metric computation              88.888889
#                       predict test data                                 11.111111
# model training        compute loss                                      27.777778
#                       get pooling info                                   5.555556
#                       measure the accuracy of the model                  5.555556
#                       model training                                    16.666667
#                       one model step training                           27.777778
#                       training precedure                                 5.555556
#                       weight normalization                              11.111111

# %%
dl_taxonomy_category_clone_type = dl_taxonomy.groupby(['dl_phase', 'sub_class','clone_type']).agg({'occs': 'sum'})
# Change: groupby  and divide by sum
dl_taxonomy_sub_cat_clone_type = dl_taxonomy_category_clone_type.groupby(level=0).apply(lambda x:
                                                 100 * x / float(x.sum()))

# %%
dl_taxonomy_sub_cat_clone_type
# Out:
#                                                                                         occs
# dl_phase              sub_class                                       clone_type
# configuration         hardware requirements                           type 1      100.000000
# data collection       load data                                       type 1       20.000000
#                                                                       type 2       20.000000
#                                                                       type 3       40.000000
#                       load label                                      type 1       20.000000
# data postprocessing   compute output shape                            type 3       12.500000
#                       object localization                             type 1       25.000000
#                                                                       type 3       12.500000
#                       process output                                  type 1       25.000000
#                                                                       type 3       12.500000
#                       set shape of output data                        type 1       12.500000
# data preprocessing    apply data augmentation                         type 1        5.555556
#                       data normalization                              type 3       11.111111
#                       get batches of data                             type 2        5.555556
#                       get numerical feature columns                   type 1        5.555556
#                                                                       type 3        5.555556
#                       parse arguments                                 type 3        5.555556
#                       prepare tensor                                  type 1       11.111111
#                       process input                                   type 3       16.666667
#                       resize image                                    type 1        5.555556
#                       set shape of input data                         type 3       11.111111
#                       set type of input data                          type 3        5.555556
#                       setting format input data                       type 3        5.555556
#                       split data                                      type 3        5.555556
# hyperparameter tuning hyperparameter tuning                           type 3      100.000000
# inference             inference                                       type 1      100.000000
# model construction    Model component format verification             type 1        2.857143
#                       activation function call                        type 3        2.857143
#                       build model                                     type 1        2.857143
#                       build one subnetwork                            type 3        2.857143
#                       compute model outputs                           type 3        2.857143
#                       init evaluation metrics                         type 3        2.857143
#                       initialize model graph                          type 3        2.857143
#                       initialize model output                         type 1        2.857143
#                       initialize weights                              type 1        2.857143
#                       layer construction                              type 2        2.857143
#                                                                       type 3        2.857143
#                       model architecture instantiation                type 3        5.714286
#                       model parameters/hyperparameters initialization type 1       14.285714
#                                                                       type 2       20.000000
#                                                                       type 3       28.571429
# model evaluation      model performance metric computation            type 2       22.222222
#                                                                       type 3       66.666667
#                       predict test data                               type 3       11.111111
# model training        compute loss                                    type 3       27.777778
#                       get pooling info                                type 3        5.555556
#                       measure the accuracy of the model               type 1        5.555556
#                       model training                                  type 1        5.555556
#                                                                       type 3       11.111111
#                       one model step training                         type 1       11.111111
#                                                                       type 2        5.555556
#                                                                       type 3       11.111111
#                       training precedure                              type 3        5.555556
#                       weight normalization                            type 3       11.111111

# %%
dl_taxonomy_sub_cat.to_csv('output_data/dl_taxonomy_sub_cat_percentage.csv')

# %%
plt.figure(figsize=(18,10))
ax=sns.countplot('clone category', data=dl_taxonomy )
plt.xticks(size=12)
plt.xlabel('clone category')
plt.yticks(size=12)
#plt.ylabel('nb_fragment', size=12)
#with_hue(ax, fcts_df.nb_fragment, 3,8)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40.]),
#  <a list of 9 Text major ticklabel objects>)

# %%
plt.figure(figsize=(14,10))
ax=sns.countplot('clone category', hue='sub_class', data=dl_taxonomy[dl_taxonomy['clone category']=='model construction'] )
plt.xticks(size=12)
plt.xlabel('clone category')
plt.yticks(size=12)
#plt.ylabel('nb_fragment', size=12)
#with_hue(ax, fcts_df.nb_fragment, 3,8)
# Out:
# (array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5]),
#  <a list of 10 Text major ticklabel objects>)

# %%
plt.figure(figsize=(14,10))
ax=sns.countplot('clone category', hue='sub_class', data=dl_taxonomy[dl_taxonomy['clone category']=='model training'] )
plt.xticks(size=12)
plt.xlabel('clone category')
plt.yticks(size=12)
#plt.ylabel('nb_fragment', size=12)
#with_hue(ax, fcts_df.nb_fragment, 3,8)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
plt.figure(figsize=(14,10))
ax=sns.countplot('clone category', hue='sub_class', data=dl_taxonomy[dl_taxonomy['clone category']=='data preprocessing'] )
plt.xticks(size=12)
plt.xlabel('clone category')
plt.yticks(size=12)
# Out:
# (array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5]),
#  <a list of 8 Text major ticklabel objects>)

# %%
plt.figure(figsize=(17,10))
ml_trad_boxplot = sns.countplot(x="dl_phase", data=dl_taxonomy, hue='clone_type')
plt.legend(loc='best')
plt.title('Clone occurrences in DL code by category and by clone type')
# Out:
# Text(0.5, 1.0, 'Clone occurrences in DL code by category and by clone type')

# %%
plt.figure(figsize=(17,10))
ml_trad_boxplot = sns.countplot(x="sub_class", data=dl_taxonomy[dl_taxonomy['dl_phase']=='model construction'], hue='clone_type')
plt.legend(loc='best')
plt.title('Clone occurrences in DL code by category and by clone type')
ml_trad_boxplot.set_xticklabels(ml_trad_boxplot.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'model parameters/hyperparameters initialization'),
#  Text(0, 0, 'initialize model graph'),
#  Text(0, 0, 'Model component format verification'),
#  Text(0, 0, 'initialize model output'),
#  Text(0, 0, 'model architecture instantiation'),
#  Text(0, 0, 'layer construction'),
#  Text(0, 0, 'activation function call'),
#  Text(0, 0, 'compute model outputs'),
#  Text(0, 0, 'build one subnetwork'),
#  Text(0, 0, 'init evaluation metrics'),
#  Text(0, 0, 'build model'),
#  Text(0, 0, 'initialize weights')]

# %%
dl_taxonomy[dl_taxonomy['dl_phase']=='model construction']
# Out:
#     repoName  classid  g  similarity  \
# 3   BerryNet       26  f         100
# 4   BerryNet       27  f         100
# 6   BerryNet       27  f          71
# 13  BerryNet       21  f         100
# 16  BerryNet       16  f         100
# 20  BerryNet       19  f          71
# 28   DeepCTR        1  f         100
# 29   DeepCTR        6  f         100
# 30   DeepCTR       12  f         100
# 31   DeepCTR        6  f          73
# 33   DeepCTR       15  f          89
# 35   DeepCTR       17  f          70
# 36   DeepCTR       19  f          71
# 37   DeepCTR       20  f          70
# 38   DeepCTR       23  f          70
# 43   DeepCTR       22  f          72
# 46   DeepCTR        1  f         100
# 47   DeepCTR       10  f         100
# 48    adanet       38  f          80
# 50    adanet       45  f          90
# 51    adanet       43  f          70
# 52    adanet       31  f          77
# 57    adanet        3  f          87
# 60    adanet       28  f          75
# 64    adanet        4  f         100
# 65    adanet       19  f         100
# 66    adanet       18  f         100
# 68    adanet        2  f         100
# 69    adanet        3  f         100
# 70    adanet        2  f          80
# 71    adanet        9  f          75
# 76    nn-wtf        5  f          77
# 83   ranking        5  f         100
# 89   ranking        3  f         100
# 93   ranking        7  f         100
#
#                                                 files  \
# 3   ['../clone_code/dl/BerryNet/berrynet/service/t...
# 4   ['../clone_code/dl/BerryNet/berrynet/service/t...
# 6   {'../clone_code/dl/BerryNet/berrynet/service/t...
# 13  {'../clone_code/dl/BerryNet/inference/enginese...
# 16  {'../clone_code/dl/BerryNet/berrynet/engine/mo...
# 20  {'../clone_code/dl/BerryNet/berrynet/engine/mo...
# 28  {'../clone_code/dl/DeepCTR/deepctr/contrib/rnn...
# 29  {'../clone_code/dl/DeepCTR/deepctr/contrib/rnn...
# 30  ['../clone_code/dl/DeepCTR/deepctr/layers/norm...
# 31  {'../clone_code/dl/DeepCTR/deepctr/models/auto...
# 33  {'../clone_code/dl/DeepCTR/deepctr/contrib/rnn...
# 35  {'../clone_code/dl/DeepCTR/deepctr/layers/inte...
# 36  {'../clone_code/dl/DeepCTR/deepctr/layers/sequ...
# 37  {'../clone_code/dl/DeepCTR/deepctr/layers/sequ...
# 38  {'../clone_code/dl/DeepCTR/deepctr/layers/inte...
# 43  {'../clone_code/dl/DeepCTR/deepctr/layers/util...
# 46  ['../clone_code/dl/DeepCTR/deepctr/contrib/uti...
# 47  ['../clone_code/dl/DeepCTR/deepctr/layers/sequ...
# 48  {'../clone_code/dl/adanet/research/improve_nas...
# 50  {'../clone_code/dl/adanet/research/improve_nas...
# 51  {'../clone_code/dl/adanet/research/improve_nas...
# 52  {'../clone_code/dl/adanet/adanet/autoensemble/...
# 57  {'../clone_code/dl/adanet/adanet/ensemble/stra...
# 60  {'../clone_code/dl/adanet/adanet/core/testing_...
# 64  {'../clone_code/dl/adanet/research/improve_nas...
# 65  ['../clone_code/dl/adanet/research/improve_nas...
# 66  ['../clone_code/dl/adanet/research/improve_nas...
# 68  {'../clone_code/dl/adanet/adanet/core/testing_...
# 69  {'../clone_code/dl/adanet/adanet/experimental/...
# 70  {'../clone_code/dl/adanet/adanet/core/estimato...
# 71  {'../clone_code/dl/adanet/adanet/autoensemble/...
# 76  {'../clone_code/dl/nn-wtf/nn_wtf/predictor.py....
# 83  {'../clone_code/dl/ranking/tensorflow_ranking/...
# 89  {'../clone_code/dl/ranking/tensorflow_ranking/...
# 93  ['../clone_code/dl/ranking/tensorflow_ranking/...
#
#                                            startlines  \
# 3                                            [32, 37]
# 4                                [36, 37, 49, 84, 85]
# 6                            {32, 36, 37, 49, 84, 85}
# 13                                           {24, 43}
# 16                                           {33, 28}
# 20                                       {33, 50, 28}
# 28                                           {56, 67}
# 29                                        {1275, 987}
# 30                                           [34, 15]
# 31                                           {17, 20}
# 33                                         {802, 678}
# 35                                     {162, 134, 54}
# 36  {385, 137, 523, 1041, 408, 35, 814, 180, 696, ...
# 37  {704, 32, 34, 777, 650, 139, 45, 15, 913, 49, ...
# 38                                         {216, 640}
# 43                                         {186, 180}
# 46                                         [172, 287]
# 47                                          [134, 54]
# 48                                     {153, 149, 41}
# 50                                    {300, 405, 350}
# 51                                          {104, 77}
# 52                                         {177, 359}
# 57                                          {88, 100}
# 60                                         {337, 389}
# 64                                           {41, 42}
# 65                                         [405, 350]
# 66                                         [228, 166]
# 68                                           {42, 29}
# 69                                         {114, 174}
# 70                                     {245, 228, 45}
# 71                                          {97, 141}
# 76                                            {8, 17}
# 83                                         {525, 438}
# 89                                          {97, 228}
# 93                      [161, 35, 138, 281, 28, 1087]
#
#                                              endlines  nb_fragment  \
# 3                                            [41, 36]            2
# 4                                [41, 42, 54, 89, 90]            5
# 6                            {36, 41, 42, 54, 89, 90}            6
# 13                                           {32, 51}            2
# 16                                           {36, 31}            2
# 20                                       {36, 55, 31}            3
# 28                                           {67, 78}            2
# 29                                        {1282, 994}            2
# 30                                           [19, 38]            2
# 31                                           {88, 75}            2
# 33                                        {892, 1148}            2
# 35                                     {170, 59, 139}            3
# 36  {391, 143, 528, 1044, 415, 38, 819, 184, 702, ...           22
# 37  {993, 36, 38, 710, 654, 782, 19, 147, 918, 55,...           12
# 38                                         {646, 222}            2
# 43                                         {192, 185}            2
# 46                                         [312, 197]            2
# 47                                          [59, 139]            2
# 48                                     {153, 44, 157}            3
# 50                                    {456, 401, 346}            3
# 51                                         {120, 103}            2
# 52                                         {414, 222}            2
# 57                                          {96, 108}            2
# 60                                         {434, 388}            2
# 64                                           {50, 51}            2
# 65                                         [456, 401]            2
# 66                                         [234, 181]            2
# 68                                           {49, 36}            2
# 69                                         {128, 189}            2
# 70                                     {48, 248, 231}            3
# 71                                         {146, 103}            2
# 76                                           {24, 17}            2
# 83                                         {536, 449}            2
# 89                                         {105, 236}            2
# 93                      [1090, 164, 38, 141, 284, 31]            6
#
#    granularity clone_type   project_type  category  locc  \
# 3     Function     type 2  Deep Learning         1     5
# 4     Function     type 2  Deep Learning         1     6
# 6     Function     type 3  Deep Learning         1     6
# 13    Function     type 1  Deep Learning         2     9
# 16    Function     type 1  Deep Learning         2     4
# 20    Function     type 3  Deep Learning         2     6
# 28    Function     type 1  Deep Learning         1    12
# 29    Function     type 1  Deep Learning         1     8
# 30    Function     type 2  Deep Learning         1     5
# 31    Function     type 3  Deep Learning         1    69
# 33    Function     type 3  Deep Learning         1   215
# 35    Function     type 3  Deep Learning         1     9
# 36    Function     type 3  Deep Learning         1     5
# 37    Function     type 3  Deep Learning         1    11
# 38    Function     type 3  Deep Learning         1     7
# 43    Function     type 3  Deep Learning         0     7
# 46    Function     type 2  Deep Learning         0    26
# 47    Function     type 2  Deep Learning         0     6
# 48    Function     type 3  Deep Learning         1     4
# 50    Function     type 3  Deep Learning         0    52
# 51    Function     type 3  Deep Learning         0    27
# 52    Function     type 3  Deep Learning         0    56
# 57    Function     type 3  Deep Learning         0     9
# 60    Function     type 3  Deep Learning         0    52
# 64    Function     type 1  Deep Learning         1    10
# 65    Function     type 2  Deep Learning         0    52
# 66    Function     type 2  Deep Learning         0    16
# 68    Function     type 1  Deep Learning         2     8
# 69    Function     type 1  Deep Learning         0    16
# 70    Function     type 3  Deep Learning         2     4
# 71    Function     type 3  Deep Learning         2     7
# 76    Function     type 3  Deep Learning         2     8
# 83    Function     type 1  Deep Learning         0    12
# 89    Function     type 1  Deep Learning         1     9
# 93    Function     type 2  Deep Learning         1     4
#
#            clone category            dl_phase  \
# 3          Same directory  model construction
# 4          Same directory  model construction
# 6          Same directory  model construction
# 13  Different directories  model construction
# 16  Different directories  model construction
# 20  Different directories  model construction
# 28         Same directory  model construction
# 29         Same directory  model construction
# 30         Same directory  model construction
# 31         Same directory  model construction
# 33         Same directory  model construction
# 35         Same directory  model construction
# 36         Same directory  model construction
# 37         Same directory  model construction
# 38         Same directory  model construction
# 43              Same file  model construction
# 46              Same file  model construction
# 47              Same file  model construction
# 48         Same directory  model construction
# 50              Same file  model construction
# 51              Same file  model construction
# 52              Same file  model construction
# 57              Same file  model construction
# 60              Same file  model construction
# 64         Same directory  model construction
# 65              Same file  model construction
# 66              Same file  model construction
# 68  Different directories  model construction
# 69              Same file  model construction
# 70  Different directories  model construction
# 71  Different directories  model construction
# 76  Different directories  model construction
# 83              Same file  model construction
# 89         Same directory  model construction
# 93         Same directory  model construction
#
#                                           sub_class  \
# 3   model parameters/hyperparameters initialization
# 4   model parameters/hyperparameters initialization
# 6   model parameters/hyperparameters initialization
# 13  model parameters/hyperparameters initialization
# 16  model parameters/hyperparameters initialization
# 20                           initialize model graph
# 28              Model component format verification
# 29                          initialize model output
# 30  model parameters/hyperparameters initialization
# 31                 model architecture instantiation
# 33                 model architecture instantiation
# 35                               layer construction
# 36  model parameters/hyperparameters initialization
# 37  model parameters/hyperparameters initialization
# 38  model parameters/hyperparameters initialization
# 43                         activation function call
# 46  model parameters/hyperparameters initialization
# 47                               layer construction
# 48                            compute model outputs
# 50  model parameters/hyperparameters initialization
# 51  model parameters/hyperparameters initialization
# 52  model parameters/hyperparameters initialization
# 57                             build one subnetwork
# 60                          init evaluation metrics
# 64  model parameters/hyperparameters initialization
# 65  model parameters/hyperparameters initialization
# 66  model parameters/hyperparameters initialization
# 68  model parameters/hyperparameters initialization
# 69                                      build model
# 70  model parameters/hyperparameters initialization
# 71  model parameters/hyperparameters initialization
# 76  model parameters/hyperparameters initialization
# 83  model parameters/hyperparameters initialization
# 89                               initialize weights
# 93  model parameters/hyperparameters initialization
#
#                                              comments  occs
# 3                                init classif service     1
# 4           initializing model parameters with config     1
# 6           initializing model parameters with config     1
# 13                                                NaN     1
# 16                                                NaN     1
# 20  init model graph classes and labels Ones with ...     1
# 28           Checks that a given object is an RNNCell     1
# 29                                 create zero arrays     1
# 30    initialize axis epsilon and layer normalization     1
# 31  Instantiates the AutoInt Deep and cross networ...     1
# 33  Creates a recurrent neural network specified b...     1
# 35  pooling layer construction with as input the s...     1
# 36       get base model configuration such as epsilon     1
# 37       get base model configuration such as epsilon     1
# 38  get base model configuration such as the use o...     1
# 43  call from library like Tensorflow type3 becaus...     1
# 46      init num units; activation fct; bias init etc     1
# 47  pooling layer construction with as input the s...     1
# 48   computing the outputs of the network can hand...     1
# 50  build model with different like default image ...     1
# 51                               hyperparameters init     1
# 52              evaluator metric config max iteration     1
# 57  generate_ensemble_candidates Produces a model ...     1
# 60  init metrics and architecture metrics to evalu...     1
# 64            hyperparameter init seed default params     1
# 65        hyperparameter init nasnet mobile and large     1
# 66              get number of layers and filter shape     1
# 68  dummy tensor Returns a randomly initialized te...     1
# 69  optimizer architecure activation adding layers...     1
# 70                            seed name server params     1
# 71  name layer size config seed adding logits last...     1
# 76  get base model configuration such as the optim...     1
# 83                          name of model weight init     1
# 89  Get weights tensor from features and reshape i...     1
# 93                                       set up model     1

# %%
plt.figure(figsize=(14,10))
ml_trad_boxplot = sns.countplot(x="dl_phase", data=dl_taxonomy[dl_taxonomy['dl_phase']=='model construction'], hue='clone_type')
plt.legend(loc='best')
plt.title('Clone occurrences in DL code by category and by clone type')
# Out:
# Text(0.5, 1.0, 'Clone occurrences in DL code by category and by clone type')
